# %%
# !pip install ipython-sql
# Out:
# Requirement already satisfied: ipython-sql in c:\users\v-kgordon\anaconda3\lib\site-packages (0.4.0)
# Requirement already satisfied: prettytable<1 in c:\users\v-kgordon\anaconda3\lib\site-packages (from ipython-sql) (0.7.2)
# Requirement already satisfied: sqlparse in c:\users\v-kgordon\anaconda3\lib\site-packages (from ipython-sql) (0.4.1)
# Requirement already satisfied: six in c:\users\v-kgordon\anaconda3\lib\site-packages (from ipython-sql) (1.15.0)
# Requirement already satisfied: ipython-genutils>=0.1.0 in c:\users\v-kgordon\anaconda3\lib\site-packages (from ipython-sql) (0.2.0)
# Requirement already satisfied: sqlalchemy>=0.6.7 in c:\users\v-kgordon\anaconda3\lib\site-packages (from ipython-sql) (1.3.20)
# Requirement already satisfied: ipython>=1.0 in c:\users\v-kgordon\anaconda3\lib\site-packages (from ipython-sql) (7.19.0)
# Requirement already satisfied: backcall in c:\users\v-kgordon\anaconda3\lib\site-packages (from ipython>=1.0->ipython-sql) (0.2.0)
# Requirement already satisfied: setuptools>=18.5 in c:\users\v-kgordon\anaconda3\lib\site-packages (from ipython>=1.0->ipython-sql) (50.3.1.post20201107)
# Requirement already satisfied: pickleshare in c:\users\v-kgordon\anaconda3\lib\site-packages (from ipython>=1.0->ipython-sql) (0.7.5)
# Requirement already satisfied: pygments in c:\users\v-kgordon\anaconda3\lib\site-packages (from ipython>=1.0->ipython-sql) (2.7.2)
# Requirement already satisfied: decorator in c:\users\v-kgordon\anaconda3\lib\site-packages (from ipython>=1.0->ipython-sql) (4.4.2)
# Requirement already satisfied: jedi>=0.10 in c:\users\v-kgordon\anaconda3\lib\site-packages (from ipython>=1.0->ipython-sql) (0.17.1)
# Requirement already satisfied: colorama; sys_platform == "win32" in c:\users\v-kgordon\anaconda3\lib\site-packages (from ipython>=1.0->ipython-sql) (0.4.4)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\v-kgordon\anaconda3\lib\site-packages (from ipython>=1.0->ipython-sql) (3.0.8)
# Requirement already satisfied: traitlets>=4.2 in c:\users\v-kgordon\anaconda3\lib\site-packages (from ipython>=1.0->ipython-sql) (5.0.5)
# Requirement already satisfied: parso<0.8.0,>=0.7.0 in c:\users\v-kgordon\anaconda3\lib\site-packages (from jedi>=0.10->ipython>=1.0->ipython-sql) (0.7.0)
# Requirement already satisfied: wcwidth in c:\users\v-kgordon\anaconda3\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=1.0->ipython-sql) (0.2.5)

# %%
# %load_ext sql

# %%
# %sql sqlite://

# %%
# %%sql
# CREATE TABLE sales
# (
#     key       varchar(6),
#     ts        timestamp,
#     product   integer,
#     completed boolean,
#     price     float
# );
# INSERT INTO sales
# VALUES ('sale_1', '2019-11-08 00:00', 0, TRUE, 1.1),
#        ('sale_2', '2019-11-08 01:00', 0, FALSE, 1.2),
#        ('sale_3', '2019-11-08 01:00', 0, TRUE, 1.3),
#        ('sale_4', '2019-11-08 01:00', 1, FALSE, 1.4),
#        ('sale_5', '2019-11-08 02:00', 1, TRUE, 1.5),
#        ('sale_6', '2019-11-08 02:00', 1, TRUE, 1.5);
# Out:
#  * sqlite://
# Done.
# 6 rows affected.
# []

# %%
# %%sql
# select * from sales;
# Out:
#  * sqlite://
# Done.
# [('sale_1', '2019-11-08 00:00', 0, 1, 1.1),
#  ('sale_2', '2019-11-08 01:00', 0, 0, 1.2),
#  ('sale_3', '2019-11-08 01:00', 0, 1, 1.3),
#  ('sale_4', '2019-11-08 01:00', 1, 0, 1.4),
#  ('sale_5', '2019-11-08 02:00', 1, 1, 1.5),
#  ('sale_6', '2019-11-08 02:00', 1, 1, 1.5)]

# %%
result = _

# %%
type(result)
# sql.run.ResultSet
# Out:
# sql.run.ResultSet

# %%
df = result.DataFrame()

# %%
df.price.hist()
# Out:
# <AxesSubplot:>

# %%
import numpy as np
import pandas as pd

# %%
df = pd.DataFrame(np.random.randint(0, 100, size=(15, 4)), columns=list("ABCD"))

# %%
df.style.background_gradient(cmap="Blues")
# Out:
# <style  type="text/css" >
# #T_792c5c23_ccaf_11eb_9b43_6ca1001d2f38row0_col0{
#             background-color:  #95c5df;
#             color:  #000000;
#         }#T_792c5c23_ccaf_11eb_9b43_6ca1001d2f38row0_col1,#T_792c5c23_ccaf_11eb_9b43_6ca1001d2f38row13_col0,#T_792c5c23_ccaf_11eb_9b43_6ca1001d2f38row13_col3,#T_792c5c23_ccaf_11eb_9b43_6ca1001d2f38row14_col2{
#             background-color:  #f7fbff;
#             color:  #000000;
#         }#T_792c5c23_ccaf_11eb_9b43_6ca1001d2f38row0_col2,#T_792c5c23_ccaf_11eb_9b43_6ca1001d2f38row1_col0{
#             background-color:  #084990;
#             color:  #f1f1f1;
#         }#T_792c5c23_ccaf_11eb_9b43_6ca1001d2f38row0_col3{
#             background-color:  #9cc9e1;
#             color:  #000000;
#         }#T_792c5c23_ccaf_11eb_9b43_6ca1001d2f38row1_col1{
#             background-color:  #084184;
#             color:  #f1f1f1;
#         }#T_792c5c23_ccaf_11eb_9b43_6ca1001d2f38row1_col2{
#             background-color:  #eef5fc;
#             color:  #000000;
#         }#T_792c5c23_ccaf_11eb_9b43_6ca1001d2f38row1_col3{
#             background-color:  #cadef0;
#             color:  #000000;
#         }#T_792c5c23_ccaf_11eb_9b43_6ca1001d2f38row2_col0{
#             background-color:  #ddeaf7;
#             color:  #000000;
#         }#T_792c5c23_ccaf_11eb_9b43_6ca1001d2f38row2_col1,#T_792c5c23_ccaf_11eb_9b43_6ca1001d2f38row8_col1{
#             background-color:  #5da5d1;
#             color:  #000000;
#         }#T_792c5c23_ccaf_11eb_9b43_6ca1001d2f38row2_col2,#T_792c5c23_ccaf_11eb_9b43_6ca1001d2f38row10_col2{
#             background-color:  #0b559f;
#             color:  #f1f1f1;
#         }#T_792c5c23_ccaf_11eb_9b43_6ca1001d2f38row2_col3{
#             background-color:  #5ca4d0;
#             color:  #000000;
#         }#T_792c5c23_ccaf_11eb_9b43_6ca1001d2f38row3_col0{
#             background-color:  #2070b4;
#             color:  #f1f1f1;
#         }#T_792c5c23_ccaf_11eb_9b43_6ca1001d2f38row3_col1{
#             background-color:  #115ca5;
#             color:  #f1f1f1;
#         }#T_792c5c23_ccaf_11eb_9b43_6ca1001d2f38row3_col2{
#             background-color:  #105ba4;
#             color:  #f1f1f1;
#         }#T_792c5c23_ccaf_11eb_9b43_6ca1001d2f38row3_col3{
#             background-color:  #65aad4;
#             color:  #000000;
#         }#T_792c5c23_ccaf_11eb_9b43_6ca1001d2f38row4_col0{
#             background-color:  #083b7c;
#             color:  #f1f1f1;
#         }#T_792c5c23_ccaf_11eb_9b43_6ca1001d2f38row4_col1{
#             background-color:  #4594c7;
#             color:  #000000;
#         }#T_792c5c23_ccaf_11eb_9b43_6ca1001d2f38row4_col2{
#             background-color:  #8dc1dd;
#             color:  #000000;
#         }#T_792c5c23_ccaf_11eb_9b43_6ca1001d2f38row4_col3{
#             background-color:  #a9cfe5;
#             color:  #000000;
#         }#T_792c5c23_ccaf_11eb_9b43_6ca1001d2f38row5_col0{
#             background-color:  #083573;
#             color:  #f1f1f1;
#         }#T_792c5c23_ccaf_11eb_9b43_6ca1001d2f38row5_col1{
#             background-color:  #f5fafe;
#             color:  #000000;
#         }#T_792c5c23_ccaf_11eb_9b43_6ca1001d2f38row5_col2{
#             background-color:  #84bcdb;
#             color:  #000000;
#         }#T_792c5c23_ccaf_11eb_9b43_6ca1001d2f38row5_col3{
#             background-color:  #084e98;
#             color:  #f1f1f1;
#         }#T_792c5c23_ccaf_11eb_9b43_6ca1001d2f38row6_col0,#T_792c5c23_ccaf_11eb_9b43_6ca1001d2f38row7_col2,#T_792c5c23_ccaf_11eb_9b43_6ca1001d2f38row10_col3,#T_792c5c23_ccaf_11eb_9b43_6ca1001d2f38row14_col1{
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }#T_792c5c23_ccaf_11eb_9b43_6ca1001d2f38row6_col1{
#             background-color:  #d8e7f5;
#             color:  #000000;
#         }#T_792c5c23_ccaf_11eb_9b43_6ca1001d2f38row6_col2,#T_792c5c23_ccaf_11eb_9b43_6ca1001d2f38row7_col3{
#             background-color:  #1561a9;
#             color:  #f1f1f1;
#         }#T_792c5c23_ccaf_11eb_9b43_6ca1001d2f38row6_col3,#T_792c5c23_ccaf_11eb_9b43_6ca1001d2f38row8_col2{
#             background-color:  #f0f6fd;
#             color:  #000000;
#         }#T_792c5c23_ccaf_11eb_9b43_6ca1001d2f38row7_col0{
#             background-color:  #abd0e6;
#             color:  #000000;
#         }#T_792c5c23_ccaf_11eb_9b43_6ca1001d2f38row7_col1{
#             background-color:  #9fcae1;
#             color:  #000000;
#         }#T_792c5c23_ccaf_11eb_9b43_6ca1001d2f38row8_col0{
#             background-color:  #084c95;
#             color:  #f1f1f1;
#         }#T_792c5c23_ccaf_11eb_9b43_6ca1001d2f38row8_col3{
#             background-color:  #1a68ae;
#             color:  #f1f1f1;
#         }#T_792c5c23_ccaf_11eb_9b43_6ca1001d2f38row9_col0{
#             background-color:  #cfe1f2;
#             color:  #000000;
#         }#T_792c5c23_ccaf_11eb_9b43_6ca1001d2f38row9_col1{
#             background-color:  #5aa2cf;
#             color:  #000000;
#         }#T_792c5c23_ccaf_11eb_9b43_6ca1001d2f38row9_col2{
#             background-color:  #a0cbe2;
#             color:  #000000;
#         }#T_792c5c23_ccaf_11eb_9b43_6ca1001d2f38row9_col3{
#             background-color:  #b0d2e7;
#             color:  #000000;
#         }#T_792c5c23_ccaf_11eb_9b43_6ca1001d2f38row10_col0{
#             background-color:  #c7dbef;
#             color:  #000000;
#         }#T_792c5c23_ccaf_11eb_9b43_6ca1001d2f38row10_col1{
#             background-color:  #0e59a2;
#             color:  #f1f1f1;
#         }#T_792c5c23_ccaf_11eb_9b43_6ca1001d2f38row11_col0{
#             background-color:  #0f5aa3;
#             color:  #f1f1f1;
#         }#T_792c5c23_ccaf_11eb_9b43_6ca1001d2f38row11_col1{
#             background-color:  #d6e5f4;
#             color:  #000000;
#         }#T_792c5c23_ccaf_11eb_9b43_6ca1001d2f38row11_col2{
#             background-color:  #083c7d;
#             color:  #f1f1f1;
#         }#T_792c5c23_ccaf_11eb_9b43_6ca1001d2f38row11_col3{
#             background-color:  #2171b5;
#             color:  #f1f1f1;
#         }#T_792c5c23_ccaf_11eb_9b43_6ca1001d2f38row12_col0{
#             background-color:  #3f8fc5;
#             color:  #000000;
#         }#T_792c5c23_ccaf_11eb_9b43_6ca1001d2f38row12_col1{
#             background-color:  #f1f7fd;
#             color:  #000000;
#         }#T_792c5c23_ccaf_11eb_9b43_6ca1001d2f38row12_col2{
#             background-color:  #3d8dc4;
#             color:  #000000;
#         }#T_792c5c23_ccaf_11eb_9b43_6ca1001d2f38row12_col3{
#             background-color:  #92c4de;
#             color:  #000000;
#         }#T_792c5c23_ccaf_11eb_9b43_6ca1001d2f38row13_col1{
#             background-color:  #81badb;
#             color:  #000000;
#         }#T_792c5c23_ccaf_11eb_9b43_6ca1001d2f38row13_col2{
#             background-color:  #539ecd;
#             color:  #000000;
#         }#T_792c5c23_ccaf_11eb_9b43_6ca1001d2f38row14_col0{
#             background-color:  #75b4d8;
#             color:  #000000;
#         }#T_792c5c23_ccaf_11eb_9b43_6ca1001d2f38row14_col3{
#             background-color:  #1c6bb0;
#             color:  #f1f1f1;
#         }</style><table id="T_792c5c23_ccaf_11eb_9b43_6ca1001d2f38" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >A</th>        <th class="col_heading level0 col1" >B</th>        <th class="col_heading level0 col2" >C</th>        <th class="col_heading level0 col3" >D</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_792c5c23_ccaf_11eb_9b43_6ca1001d2f38level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_792c5c23_ccaf_11eb_9b43_6ca1001d2f38row0_col0" class="data row0 col0" >41</td>
#                         <td id="T_792c5c23_ccaf_11eb_9b43_6ca1001d2f38row0_col1" class="data row0 col1" >3</td>
#                         <td id="T_792c5c23_ccaf_11eb_9b43_6ca1001d2f38row0_col2" class="data row0 col2" >76</td>
#                         <td id="T_792c5c23_ccaf_11eb_9b43_6ca1001d2f38row0_col3" class="data row0 col3" >33</td>
#             </tr>
#             <tr>
#                         <th id="T_792c5c23_ccaf_11eb_9b43_6ca1001d2f38level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_792c5c23_ccaf

# %%
df["B"] *= 1000
#If we increase the numbers, the gradient will remain the same.

# %%
df.style.background_gradient(cmap="Spectral")
#We can randomize the colors more as well. You can see how the distinguishing effects are completely lost.
# Out:
# <style  type="text/css" >
# #T_f1da362c_ccaf_11eb_a9b5_6ca1001d2f38row0_col0{
#             background-color:  #fede89;
#             color:  #000000;
#         }#T_f1da362c_ccaf_11eb_a9b5_6ca1001d2f38row0_col1,#T_f1da362c_ccaf_11eb_a9b5_6ca1001d2f38row13_col0,#T_f1da362c_ccaf_11eb_a9b5_6ca1001d2f38row13_col3,#T_f1da362c_ccaf_11eb_a9b5_6ca1001d2f38row14_col2{
#             background-color:  #9e0142;
#             color:  #f1f1f1;
#         }#T_f1da362c_ccaf_11eb_a9b5_6ca1001d2f38row0_col2,#T_f1da362c_ccaf_11eb_a9b5_6ca1001d2f38row1_col0{
#             background-color:  #3585bb;
#             color:  #000000;
#         }#T_f1da362c_ccaf_11eb_a9b5_6ca1001d2f38row0_col3{
#             background-color:  #fed683;
#             color:  #000000;
#         }#T_f1da362c_ccaf_11eb_a9b5_6ca1001d2f38row1_col1{
#             background-color:  #4273b3;
#             color:  #000000;
#         }#T_f1da362c_ccaf_11eb_a9b5_6ca1001d2f38row1_col2{
#             background-color:  #b81e48;
#             color:  #f1f1f1;
#         }#T_f1da362c_ccaf_11eb_a9b5_6ca1001d2f38row1_col3{
#             background-color:  #f67f4b;
#             color:  #000000;
#         }#T_f1da362c_ccaf_11eb_a9b5_6ca1001d2f38row2_col0{
#             background-color:  #de4c4b;
#             color:  #000000;
#         }#T_f1da362c_ccaf_11eb_a9b5_6ca1001d2f38row2_col1,#T_f1da362c_ccaf_11eb_a9b5_6ca1001d2f38row8_col1{
#             background-color:  #f5fbaf;
#             color:  #000000;
#         }#T_f1da362c_ccaf_11eb_a9b5_6ca1001d2f38row2_col2,#T_f1da362c_ccaf_11eb_a9b5_6ca1001d2f38row10_col2{
#             background-color:  #47a0b3;
#             color:  #000000;
#         }#T_f1da362c_ccaf_11eb_a9b5_6ca1001d2f38row2_col3{
#             background-color:  #f4faad;
#             color:  #000000;
#         }#T_f1da362c_ccaf_11eb_a9b5_6ca1001d2f38row3_col0{
#             background-color:  #86cfa5;
#             color:  #000000;
#         }#T_f1da362c_ccaf_11eb_a9b5_6ca1001d2f38row3_col1{
#             background-color:  #56b0ad;
#             color:  #000000;
#         }#T_f1da362c_ccaf_11eb_a9b5_6ca1001d2f38row3_col2{
#             background-color:  #54aead;
#             color:  #000000;
#         }#T_f1da362c_ccaf_11eb_a9b5_6ca1001d2f38row3_col3{
#             background-color:  #fbfdb8;
#             color:  #000000;
#         }#T_f1da362c_ccaf_11eb_a9b5_6ca1001d2f38row4_col0{
#             background-color:  #4b68ae;
#             color:  #f1f1f1;
#         }#T_f1da362c_ccaf_11eb_a9b5_6ca1001d2f38row4_col1{
#             background-color:  #ddf19a;
#             color:  #000000;
#         }#T_f1da362c_ccaf_11eb_a9b5_6ca1001d2f38row4_col2{
#             background-color:  #fee593;
#             color:  #000000;
#         }#T_f1da362c_ccaf_11eb_a9b5_6ca1001d2f38row4_col3{
#             background-color:  #fdc372;
#             color:  #000000;
#         }#T_f1da362c_ccaf_11eb_a9b5_6ca1001d2f38row5_col0{
#             background-color:  #555aa7;
#             color:  #f1f1f1;
#         }#T_f1da362c_ccaf_11eb_a9b5_6ca1001d2f38row5_col1{
#             background-color:  #a20643;
#             color:  #f1f1f1;
#         }#T_f1da362c_ccaf_11eb_a9b5_6ca1001d2f38row5_col2{
#             background-color:  #feec9f;
#             color:  #000000;
#         }#T_f1da362c_ccaf_11eb_a9b5_6ca1001d2f38row5_col3{
#             background-color:  #3990ba;
#             color:  #000000;
#         }#T_f1da362c_ccaf_11eb_a9b5_6ca1001d2f38row6_col0,#T_f1da362c_ccaf_11eb_a9b5_6ca1001d2f38row7_col2,#T_f1da362c_ccaf_11eb_a9b5_6ca1001d2f38row10_col3,#T_f1da362c_ccaf_11eb_a9b5_6ca1001d2f38row14_col1{
#             background-color:  #5e4fa2;
#             color:  #f1f1f1;
#         }#T_f1da362c_ccaf_11eb_a9b5_6ca1001d2f38row6_col1{
#             background-color:  #e75948;
#             color:  #000000;
#         }#T_f1da362c_ccaf_11eb_a9b5_6ca1001d2f38row6_col2,#T_f1da362c_ccaf_11eb_a9b5_6ca1001d2f38row7_col3{
#             background-color:  #60bba8;
#             color:  #000000;
#         }#T_f1da362c_ccaf_11eb_a9b5_6ca1001d2f38row6_col3,#T_f1da362c_ccaf_11eb_a9b5_6ca1001d2f38row8_col2{
#             background-color:  #b11747;
#             color:  #f1f1f1;
#         }#T_f1da362c_ccaf_11eb_a9b5_6ca1001d2f38row7_col0{
#             background-color:  #fdbf6f;
#             color:  #000000;
#         }#T_f1da362c_ccaf_11eb_a9b5_6ca1001d2f38row7_col1{
#             background-color:  #fed27f;
#             color:  #000000;
#         }#T_f1da362c_ccaf_11eb_a9b5_6ca1001d2f38row8_col0{
#             background-color:  #358bbc;
#             color:  #000000;
#         }#T_f1da362c_ccaf_11eb_a9b5_6ca1001d2f38row8_col3{
#             background-color:  #71c6a5;
#             color:  #000000;
#         }#T_f1da362c_ccaf_11eb_a9b5_6ca1001d2f38row9_col0{
#             background-color:  #f47044;
#             color:  #000000;
#         }#T_f1da362c_ccaf_11eb_a9b5_6ca1001d2f38row9_col1{
#             background-color:  #f2faaa;
#             color:  #000000;
#         }#T_f1da362c_ccaf_11eb_a9b5_6ca1001d2f38row9_col2{
#             background-color:  #fed07e;
#             color:  #000000;
#         }#T_f1da362c_ccaf_11eb_a9b5_6ca1001d2f38row9_col3{
#             background-color:  #fdb768;
#             color:  #000000;
#         }#T_f1da362c_ccaf_11eb_a9b5_6ca1001d2f38row10_col0{
#             background-color:  #f88c51;
#             color:  #000000;
#         }#T_f1da362c_ccaf_11eb_a9b5_6ca1001d2f38row10_col1{
#             background-color:  #50a9af;
#             color:  #000000;
#         }#T_f1da362c_ccaf_11eb_a9b5_6ca1001d2f38row11_col0{
#             background-color:  #52abae;
#             color:  #000000;
#         }#T_f1da362c_ccaf_11eb_a9b5_6ca1001d2f38row11_col1{
#             background-color:  #ea5e47;
#             color:  #000000;
#         }#T_f1da362c_ccaf_11eb_a9b5_6ca1001d2f38row11_col2{
#             background-color:  #496aaf;
#             color:  #f1f1f1;
#         }#T_f1da362c_ccaf_11eb_a9b5_6ca1001d2f38row11_col3{
#             background-color:  #89d0a4;
#             color:  #000000;
#         }#T_f1da362c_ccaf_11eb_a9b5_6ca1001d2f38row12_col0{
#             background-color:  #d1ed9c;
#             color:  #000000;
#         }#T_f1da362c_ccaf_11eb_a9b5_6ca1001d2f38row12_col1{
#             background-color:  #af1446;
#             color:  #f1f1f1;
#         }#T_f1da362c_ccaf_11eb_a9b5_6ca1001d2f38row12_col2{
#             background-color:  #cdeb9d;
#             color:  #000000;
#         }#T_f1da362c_ccaf_11eb_a9b5_6ca1001d2f38row12_col3{
#             background-color:  #fee18d;
#             color:  #000000;
#         }#T_f1da362c_ccaf_11eb_a9b5_6ca1001d2f38row13_col1{
#             background-color:  #feefa3;
#             color:  #000000;
#         }#T_f1da362c_ccaf_11eb_a9b5_6ca1001d2f38row13_col2{
#             background-color:  #edf8a3;
#             color:  #000000;
#         }#T_f1da362c_ccaf_11eb_a9b5_6ca1001d2f38row14_col0{
#             background-color:  #fff7b2;
#             color:  #000000;
#         }#T_f1da362c_ccaf_11eb_a9b5_6ca1001d2f38row14_col3{
#             background-color:  #79c9a5;
#             color:  #000000;
#         }</style><table id="T_f1da362c_ccaf_11eb_a9b5_6ca1001d2f38" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >A</th>        <th class="col_heading level0 col1" >B</th>        <th class="col_heading level0 col2" >C</th>        <th class="col_heading level0 col3" >D</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_f1da362c_ccaf_11eb_a9b5_6ca1001d2f38level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_f1da362c_ccaf_11eb_a9b5_6ca1001d2f38row0_col0" class="data row0 col0" >41</td>
#                         <td id="T_f1da362c_ccaf_11eb_a9b5_6ca1001d2f38row0_col1" class="data row0 col1" >3000000</td>
#                         <td id="T_f1da362c_ccaf_11eb_a9b5_6ca1001d2f38row0_col2" class="data row0 col2" >76</td>
#                         <td id="T_f1da362c_ccaf_11eb_a9b5_6ca1001d2f38row0_col3" class="data row0 col3" >33</td>
#             </tr>
#             <tr>
#                         <th id="T_f1da362c_ccaf_11eb_a9b5_6ca1001d2f38level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_f1da362
